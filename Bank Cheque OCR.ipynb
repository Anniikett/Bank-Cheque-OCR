# %%
# pip install pytesseract==0.3.4

# %%
from PIL import Image
from io import BytesIO
import cv2
import numpy as np
import pytesseract as pyt
import matplotlib.pyplot as plt
import re

# %%
pyt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread("DATA/1.jpg")

# %%
plt.imshow(img)

# %%
img = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img, cmap="gray")

# %%
text = pyt.image_to_string(img, lang="eng")

# %%
text
# Out:
# 'UTILITY FORMS PVT.LTD. / CTs - 2010\n\nH SBC Advance Valid for three months from the date of issuance\nBae D- DOM MON ee\n\nThe Hongkong and Shanghai Bankin i imi\ng Corporation Limited\nPlot No. 139-140 B, Western Express Highway Sahar Road Junction, Vile Parle (East) Mumbai - 400057\nPayable at par at all HSBC branches in India\n\nIFSC HSBC0400003\na Ra HI Or Bearer\n\nPay\n\neu Rupees ,\n\n=a, a\ni madiort\nAlcNo. | ()03-484540-006\n\n \n\n \n\n \n\nYATIN VASANT PEDNEKAR\nPlease sign above\n\nvw 208556" 400039004" W50005" 4k\n\nrr'

# %%
# function to remove noise and unnecessary characters from string
def clean_text(text):
    if text != ' ' or text != '  ' or text != '':
        text = re.sub('[^A-Za-z0-9-/,.() ]+', '', text)
        text = text.strip()
        text = re.sub(r'\s{2,}', ' ', text)

    return text

# %%
text_clean = clean_text(text)

# %%
text_clean
# Out:
# 'UTILITY FORMS PVT.LTD. / CTs - 2010H SBC Advance Valid for three months from the date of issuanceBae D- DOM MON eeThe Hongkong and Shanghai Bankin i imig Corporation LimitedPlot No. 139-140 B, Western Express Highway Sahar Road Junction, Vile Parle (East) Mumbai - 400057Payable at par at all HSBC branches in IndiaIFSC HSBC0400003a Ra HI Or BearerPayeu Rupees ,a, ai madiortAlcNo. ()03-484540-006 YATIN VASANT PEDNEKARPlease sign abovevw 208556 400039004 W50005 4krr'

# %%
micr_img = img[1850:,:]

# %%
plt.imshow(micr_img, cmap="gray")

# %%
text = pyt.image_to_string(micr_img, "eng")

# %%
text

# %%
text = pyt.image_to_string(micr_img, lang="mcr")

# %% [raw]
# Note: If you face this error the follow the belwo step
#
# TesseractError: (1, 'Error opening data file C:\\Program Files\\Tesseract-OCR/tessdata/mcr.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'mcr\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
#
#
# step 1:
# Download the mcr.trainedata file from this link
#
# https://raw.githubusercontent.com/BigPino67/Tesseract-MICR-OCR/master/Tessdata/mcr.traineddata
#
# step 2:
# Paste this file inside tessdata
# loc: C:\Program Files\Tesseract-OCR\tessdata
#
# run again

# %%
plt.imshow(micr_img)

# %%
text
# Out:
# 'c208556c 40003900308 950003c 31'

# %%
clean_text(text)
# Out:
# 'c208556c 40003900308 950003c 31'

# %%
digit = cv2.imread("MCR_digit.png")
plt.imshow(digit)
